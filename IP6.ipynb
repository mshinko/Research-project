# %% [markdown]
# <a href="https://colab.research.google.com/github/mshinko/Research-project/blob/main/IP6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets evaluate transformers[torch]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 28.1 MB/s eta 0:00:00
# ...

# %%
# !pip install -q transformers einops accelerate langchain bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 23.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 18.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.4/181.4 kB 22.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.9 MB/s eta 0:00:00

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) y
# Token is valid (permission: read).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# ...

# %%
import pandas as pd

objectives2 = """
Objectives
During the next four months, Oceanic Reef Restorers will:


1.Embark – precision planning comes together through our team on the road to achieving company goals
2.Create – turn product and process ideation into viable service procedures that can stimulate funding
3.Launch – release functioning website, social media, and brand awareness campaigns

4.Develop and launch a fully functioning website—Continue to develop and update our beta site using customer feedback and user testing to design an attention-grabbing platform that drives continued views.
5.Secure appropriate funding to scale—acquire the necessary resources to continue to grow. Explore which global markets will offer the best opportunity for expansion.
6.Develop and test absorption post prototype—Design, produce, and test a small-scale prototype. Discover what sort of scale needs to be implemented for optimal results.
7.Decide which area(s) are ideal for venture launch—Discover which key reef colonies need the greatest help whilst also offering a host nation that is willing to help foster successful progress.
"""
df4 = pd.DataFrame({'Objectives': [objectives2]})

# %%
import pandas as pd

objectives3 = """
Objectives
During the next week, the company will:
1. Write out a full business plan – Identify the place in the market our
business will fill as well as meet regarding what our goals should be by
the end of the semester
2. Come up with a company name
3. Finish MOKR
4. Team building meeting - Meet outside of class to get to know each other
5. Look at existing rings - Find out how to make them better
"""
df7 = pd.DataFrame({'Objectives': [objectives3]})

# %%
import pandas as pd

objectives = """
  1. Investigate possible competitors – Understand what sports teams and
streaming providers have already accomplished in the world of virtual
reality and how VRSS can become a leader in the market.
2. Define intended customers - Identify the intended target market for this
service. Create 2 customer profiles that represent the target market so that
10 adequate customer needs can be developed.
3. Identify a possible streaming method - Figure out the best way to record,
stream, and allow an audience of 50+ people to watch a sports game using
a few, budget-friendly video cameras.
4. Develop and launch a prototype website—Develop and update a
prototype site based on customer needs that is easy to use and provides
access to a VR video stream.
5. Apply for funding to expand—Acquire necessary resources to continue to
grow. Explore which national markets will offer the best opportunity for
expansion.
"""
df2 = pd.DataFrame({'Objectives': [objectives]})

# %%
import pandas as pd

# Use triple-quoted strings to preserve the formatting
original_text = """
  To: VRSS Management Team
    From: David Schlingloff
    Subject: VRSS Management Report – Week ending January 30th, 2022
    Copies: Management Team, Advisors

    Priorities
    We are working on these priorities:
    1. Finalize a set of interested and motivated team members.
    2. Define competitors to the VRSS product.
    3. Identify possible methods of VR streaming.

    Progress
    During this (short) reporting period, we accomplished these tasks:
    - Developed the idea and company:
      - Brainstormed possible ideas to pursue and decided upon the VR service.
      - Created a name for the company (Virtual Reality Sports Seating - VRSS).
    - Founded the Team:
      - Confirmed 4 teammates (we may accept more in the following days).
      - Drafted our MOKRs for discussion.

    Plans
    During the next week, we plan to finish these tasks:
    - Find 5 competitors to the planned VRSS service:
      - Perform research online to develop 5 possible competitors (both direct and indirect) to VRSS service by Friday, February 4th (Alex, Ryan, Matt).
    - Brainstorm 4 VR streaming-capable cameras:
      - Find 4 different types of video cameras (preferably inexpensive, <$1000) that can support VR streaming capabilities by Friday, February 4th.
      - Begin understanding the limitations of streaming bandwidth (David, Kartik).

    Problems
    We are aware of these problems:
    - We need to finalize our team:
      - There are still people who were interested in joining last week but left too early to make a final decision. We would like to complete this by the end of class on Monday, January 31st.
    - We are unsure if cameras can support our bandwidth:
      - The team would like to use a limited number of cameras that can be accessed by many different people during a game. The team is unsure if it is even possible to get these types of cameras without spending excessive amounts of money.
    - We do not currently have experience with software/website creation:
      - Much of the VRSS streaming service is dependent on a reliable stream with easy website access. A lot of our resources will need to be spent on attempting to create an appealing website with streaming capabilities.

    Management Report.doc 2022Jan30 Page 1/2

    Attachments
    - None.
"""

# Define the summary
summary = "Week 1 Created the team and MOKR. Plan to find competitors and understand technology needed. They lack the knowledge to build a streaming service solution and it is unclear who their customers are that would pay for it. Identified problems but don’t have plans for mitigating."


# Create a DataFrame
df = pd.DataFrame({'Original Text': [original_text], 'Summary': [summary]})
# Define the new row data as a dictionary
new_row = {
    'Original Text': """
    To: VRSS Management Team
    From: David Schlingloff
    Subject: VRSS Management Report – Week ending February 6th, 2022
    Copies: Management Team, Advisors

    Priorities
    We are working on these priorities:
    1. Finalize a set of interested and motivated team members.
    2. Defining competitors to the VRSS product.
    3. Identifying possible methods of VR streaming.

    Progress
    During this (short) reporting period, we accomplished these tasks:
    - Find 5 competitors to the planned VRSS service – Developed 5 possible
    competitors (both direct and indirect) to VRSS service.
    - Brainstorm 4 VR streaming capable cameras - Found 4+ different types of
    video cameras (preferably inexpensive, <$1000) that can support VR
    streaming capabilities.

    Plans
    During the next week, we plan to finish these tasks:
    - Refine our target consumers - Talk about refining the consumers we defined
    last week. Build upon this by creating 3 theoretical customer profiles (David,
    Alex, Matthew).
    - Define our advisory board - We will think about the people that would be
    helpful for us to talk to. Think about areas we could ask questions in. Using
    these topics, search for people we can possibly talk to and discuss our project
    plan. (Ryan, Entire Team).
    - Find specific details about 3 competitors - From the competitors we found
    last week, go on their websites and explore what they do and learn about
    their history. Specifically, create a document by February 11th, with the
    following 3 things noted for each: similarities/differences between company
    and VRSS, the prices for that service, and if/how they advertise. (Kartik,
    Ryan).

    Problems
    We are aware of these problems:
    - We do not currently have experience with software / website creation –
    Much of the VRSS streaming service is dependent on a reliable stream
    with easy website access. A lot of our resources will need to be spent on
    attempting to create an appealing website with streaming capabilities.
    - Defining our place in the market is tricky - The team mapped out the
    two existing markets - going to sports games and streaming them on TV.
    We realized that there is a definitive space in the market for VR streaming,
    but it might be tricky to convince the target consumers to pursue this
    option versus the others.
    - Finding VR capable equipment is expensive - VR is still a relatively new
    type of streaming, and therefore the market for this technology is still
    relatively niche. Finding equipment (like a VR capable camera) is possible,
    but our requirement of <$1000 makes it difficult.
    - Our marketing efforts/strategy is a current problem we have. In order to
    acquire a lot of customers and produce sales, our marketing and
    advertising will need to be phenomenal. We could develop a social media
    account (Instagram/Facebook) and/or pay for a commercial
    advertisement on TV.

    Management Report.doc 2022Feb06 Page 1/5

    Attachments
    - None.
    """,

 "Summary":"Week 2 Found competitors and VR streaming cameras. Plan on analyzing competition, find advisory board members, and create 3 customer profiles. They lack the knowledge to build a streaming service solution, the equipment is too expensive and it is unclear who their customers are that would pay for it. Identified problems but don’t have plans for mitigating."

}

# Append the new row to the DataFrame
df = df.append(new_row, ignore_index=True)
# Define the new row
new_row_2 = {
    'Original Text': """
   To: VRSS Management Team
From: David Schlingloff
Subject: VRSS Management Report – Week ending February 13th, 2022
Copies: Management Team, Advisors
Priorities
We are working on these priorities:
1. Gauge the interest of VR equipment with our target markets
2. Identify a way to live-stream in VR
3. Brainstorm ways to begin website creation
Progress
During this reporting period, we accomplished these tasks:
● Refined our target consumers - Developed our ideal target market by
creating 3 theoretical customer profiles based on the 3 customer groups that
the team developed.
● Defined our advisory board - Listed nine people that the team would like to
invite to the first project review meeting. Each person has different unique
talents and abilities that could help the team move forward.
● Scheduled VR equipment rental - Reserved a VR camera and VR headset at
the Virginia Tech library so that the team can begin testing with the
equipment.
● Find specific details about 3 competitors - Unable to accomplish this in the
week timeframe. The team decided that the information we already have is
enough to move forward with and we spent our resources on other tasks.
Plans
During the next week, we plan to finish these tasks:
● Create an interest survey - Use google forms to develop a survey that can
gauge the interest in this service based on the 3 target markets defined by
February 17th. Generate a list of 9 people (three from each target market) to
be sent out by February 21st. (Kartik, Ryan, Alex)
● Obtain and use VR equipment - Receive the VR camera and headset from
the Virginia Tech library and attempt to connect to the computer. See if it is
possible to first record a video in VR. Then work on streaming options if time
permits for the week. The team will research and document the process for
video recording and video streaming (if possible). (David, all team)

Management Report.doc 2022Feb13 Page 1/3

Problems
We are aware of these problems:
● We still do not currently have experience with software / website
creation – Much of the VRSS streaming service is dependent on a reliable
stream with easy website access. A lot of our resources will need to be
spent on attempting to create an appealing website with streaming
capabilities. However, we are now looking at meeting with people who do
have this experience and developing a plan of integration.
● VR equipment implementation requires resources - Although the team
was successful in figuring out a way to rent VR equipment, it has realized
that in order to record and stream video, a powerful and expensive
computer is needed. It will need to be portable so that it can be moved to
where the VR cameras are located.
● Our marketing efforts/strategy - In order to acquire a lot of customers and
produce sales, our marketing and advertising will need to be phenomenal.
We could develop a social media account (instagram/facebook) and/or
pay for
    """,
    'Summary': """
    Week 3
    Created customer profiles, list of potential advisory board members, and reserved VR equipment rentals to address the expense constraint identified last week. Failed to analyze competitors they believe they have sufficient information to move forward though not clear what that is. They plan to create an interest survey (as opposed to interviewing as indicated in MOKR) and record a VR video with rented equipment. They lack the knowledge to build a streaming service solution, the equipment is too expensive. They continue to have the same problems but don’t have plans for mitigating. Will need to intervene to get them unstuck.
    """
}


# Append the new row to the DataFrame
df = df.append(new_row_2, ignore_index=True)
new_row3 = {
    'Original Text': """
    To: VRSS Management Team
From: David Schlingloff
Subject: VRSS Management Report – Week ending March 4th, 2022
Copies: Management Team, Advisors
Priorities
We are working on these priorities:
1. Get people to take our survey and evaluate the results.
2. Identify a way to live-stream in VR
3. Submit a video to KickstartVT
Progress
During this reporting period, we accomplished these tasks:
● Analyzed interest survey results - Received 25 responses from the survey and
wrote a one-page report summarizing the key-findings from the survey that was
sent out. The team found that we should continue to pursue this product. (Matt,
Ryan, Alex)
● Obtained and use VR equipment - Obtained the Oculus Go and successfully
connected it to YouTube VR. The process was documented and an Oculus Quest
2 was scheduled for rent to attempt to do the same thing. If it works as well, then
we will discuss using the Insta360 camera to live-stream to the Oculus Quest 2.
(David, Kartik)
● Performed individual project reviews - Gave the presentation to our advisory
board members. (David, all team members)

Plans
During the next week, we plan to finish these tasks:
● Finalize interest survey results - Synthesize the survey results and add to our
report and project review presentation. (Ryan, Matt, Alex)
● Obtain and use VR equipment - Obtain the Oculus Quest 2 and see if it can
connect to YouTube VR. If so, document the process and start to discuss
live-streaming options using the Insta360 camera. (Alex, Kartik)
● Perform team project review - Revise presentation template for the class and
present the project review to the team on Wednesday, March 16th. Record the
comments from the Q&A. (David, all team members)
● Create a video for KickStartVT - Record and edit a video for KickstartVT and
submit on Sunday, March 20th. (David, all team members)

Problems
We are aware of these problems:
● We can only rent equipment for a limited period - We would like to rent an
Oculus Go or an Oculus Quest (since they are stand-alone devices), but they
require rentals so timing can get delayed significantly.
● We still do not currently have experience with software / website creation –
Much of the VRSS streaming service is dependent on a reliable stream with easy
website access. A lot of our resources will need to be spent on attempting to
create an appealing website with streaming capabilities. However, we are now
looking at meeting with people who do have this experience and developing a
plan of integration.
● Our marketing efforts/strategy - In order to acquire a lot of customers and
produce sales, our marketing and advertising will need to be aggressive. We
could develop a social media account (instagram/facebook) and/or pay for a
commercial advertisement on TV.
    """,
    'Summary': """
  Week 5
Sent out the previously created interest survey and tried out an HTC Vive but didn’t  function with Youtube App. Scheduled time with advisory board and potential team member. Plan to try an Oculus Go, analyze the survey data, and prepare for the project review. They still lack the knowledge to build a streaming service solution, the renting of the vr equipment is too burdensome  due to rental policies. They continue to have the same problems of website creation and marketing  but don’t have plans for mitigating. Will need to intervene to get them unstuck.


    """
}
df = df.append(new_row3, ignore_index=True)
# Print the updated DataFrame
print(df)
# Out:
#                                        Original Text  \
# 0  \n  To: VRSS Management Team\n    From: David ...
# 1  \n    To: VRSS Management Team\n    From: Davi...
# 2  \n   To: VRSS Management Team\nFrom: David Sch...
# 3  \n    To: VRSS Management Team\nFrom: David Sc...
#
#                                              Summary
# 0  Week 1 Created the team and MOKR. Plan to find...
# 1  Week 2 Found competitors and VR streaming came...
# 2  \n    Week 3\n    Created customer profiles, l...
# 3  \n  Week 5\nSent out the previously created in...
# <ipython-input-5-6081d995d07e>:124: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# <ipython-input-5-6081d995d07e>:191: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row_2, ignore_index=True)
# ...

# %%
""" VEATHER"""

import pandas as pd

# Use triple-quoted strings to preserve the formatting
original_text = """

	To:	Veather Management Team
	From:	Darsh Desai
	Subject:	Veather Management Report – Week ending [month day (example: December 3, 1999) – this date is the Sunday before the day you send out the management report]
	Copies:	Management Team, Advisors
Priorities
We are working on these priorities:

Finalizing the basic raw material used for the project
Focusing on our website design

Progress
During this reporting period, we accomplished these tasks:

Examples:

Gathering a team –We have brought together a team comprised of two people.
Focusing on the business model – We have created a business model so that we can scale it.



Plans

Talking with a developer on incorporating certain designs in to our website.
Showing prototypes to test subjects getting there opinion about it


Problems
We are aware of these problems:



Inability to use specialized material– A key problem that we must issue is the lack of specialized resins used in the making of leather, we are considering the use of basic glue and other substances which will allow us to mold our imperfect prototypes to counter this challenge.
Financial cost of designing a website– Designing a website that is user friendly and interactive alongside compatible with developers to make is a challenge however, since I have some experience with graphic design, I could create some basic templates of the design.


"""
df2 = pd.DataFrame({'Original Text': [original_text]})
new_row = {'Original Text':
           """

	To:	Veather Management Team Management Team
	From:	Darsh Desai
	Subject:	Veather Management Report – Week ending February 6th, 2022
	Copies:	Management Team, Advisors
Priorities
We are working on these priorities:

Figuring out the ratio of the mixture involving various vegan leftovers

Progress
During this reporting period, we accomplished these tasks:


Conducting food tests– We conducted basic tests with certain organic materials by taking orange and banana peels and roasting them in the oven at a temperature of 400 degrees Fahrenheit. The results showed that the banana peels could withstand higher temperatures but brittle and the orange peels were extremely malleable but less strong than the banana peel.
Designing a logo– On the theme of using different colors, we are trying to create a decent catchy logo that resonates with our brand mission and purpose.

Problems
We are aware of these problems:

Expensive testing – We have recognized that one of the major challenges that we are facing is that we need better testing methods to help us find our material. This can be solved by using the ISE laboratory to help us.
Process of Manufacturing – The major issue is how we are going to be scaling this operation with the least amount of harmful chemicals and setting up the basic manufacturing roadmap for that. We have contacted a food science professor and are waiting for his response on getting advice for giving us a basic overview on what would be the constituent mixture. Also we are going to be talking to an experienced materials engineer who will help us in setting the default structure for the manufacturing structure.

"""
}
df2 = df2.append(new_row, ignore_index=True)
new_row_1 = {"Original Text":
             """

	To:	Veather Management Team
	From:	Darsh Desai
	Subject:	Veather Management Report – Week ending Feb 14th , 2022
	Copies:	Management Team, Advisors
Priorities
We are working on these priorities:

Figuring out the ratio of the mixture involving various vegan leftovers
Creating a coherent manufacturing policy that allows us to scale our business

Progress
During this reporting period, we accomplished these tasks:
Studying our competitors - We are closely analyzing what practices they have been involving in their business, and how are they planning to expand.
Partnerships with local establishments – We asked local establishments such as supermarkets as to the amount of fruits they throw away each week, collecting important data giving us a sense as to what would the situation be for acquiring the raw material if we were to start in Blacksburg.
Plans
During the next week, we plan to finish these tasks:
Finishing Our Logo – This will allow our brand to get an identity so that approaching people and institutions becomes easier.
Finalizing our Business plan – Focusing on this aspect becomes crucial as it is the pillar on what our next move is.

Problems
We are aware of these problems:

Inability to get advice from a Food Science expert – We contacted a number of food experts at the university but they were unable to help us. We recognize the difficulty, but our current plan is to talking to the department head if anybody is interested on advising us from the Food Science department.
Debate over business plan– Our main challenge is arriving at the type of business model. I believe that we need to vertically integrate and include the manufacturing, designing and the sale of the raw material. My colleague, however, believes in an asset light model, wherein we focus on one aspect that is production and outsource the design to another company. We are resolving to solve our differences on the matter and come up with a coherent plan.
"""}
df2= df2.append(new_row_1, ignore_index=True)
new_row_2 = {"Original Text":
             """


	To:	Veather Management Team
	From:	Darsh Desai
	Subject:	Veather Management Report – Week ending Feb 20th, 2022
	Copies:	Management Team, Advisors
Priorities
We are working on these priorities:

Figuring out the ratio of the mixture involving various vegan leftovers
Creating a coherent manufacturing policy that allows us to scale our business

Progress
During this reporting period, we accomplished these tasks:

Creating a Logo – We created a logo that resonated with our brand identity and goal as to become a leading player within the vegan leather industry.
Presentation at the Apex Centre – We were selected to pitch our idea and receive a 500 dollar grant for future expenses.
Finalizing a business plan – We have finalized that we are going to vertically integrate our manufacturing process, this will allow greater control as well as provide us with various options to expand elsewhere.


Plans
During the next week, we plan to finish these tasks:


Getting advice from an expert – We are going to be hoping for some advice from a food science expert who can help us get a better understanding of which materials we need to use.
Acquiring access to test materials – We are going to be talking to the ISE labs in helping us get access to certain specialized equipment that will allow us to do some further testing on out materials

Problems
Getting a functional Website started – A key aspect of studying other firms in the same domain, is that they have a partially operational website ie. Without selling the product. We need to come up with a basic website as well. We can fund this expense with the capital raised from KickStart VT and create a website.
Finalizing Raw Materials acquisition– We are having issues sorting out basic raw material acquisition. We do not have a steady supply of a lot of shortlisted fruits such as bananas, oranges and mangoes. We plan to go to a bigger distributor and ask if its possible to acquire in bulk
"""
}
df2 = df2.append(new_row_2, ignore_index=True)
new_row_3 = {"Original Text":
             """
             To: Veather Management Team
From: Jerry Zhou, Darsh Desai
Subject: Veather Management Report – Week ending Feb 27th
, 2022

Copies: Management Team, Advisors
Priorities
We are working on these priorities:
1. Figuring out the ratio of the mixture involving various vegan leftovers
2. Creating a coherent manufacturing policy that allows us to scale our
business

Progress
During this reporting period, we accomplished these tasks:
● Creating a Logo – We created a logo that resonated with our brand
identity and goal as to become a leading player within the vegan leather
industry.
● Presentation at the Apex Centre – We were selected to pitch our idea and
receive a 500-dollar grant for future expenses. Up to this week, we have
successfully completed the presentation and granted with $500. We will be
using this money for recruiting developers.
● Finalizing a business plan – We have finalized that we are going to
vertically integrate our manufacturing process, this will allow greater
control as well as provide us with various options to expand elsewhere.
● Seeking for recruitment of developers – As we have received the startup
fund, we have asked several departments about their interest in
participating in our project.

Plans
During the next week, we plan to finish these tasks:

● Seeking for experts who are willing to help with development – For the
past weeks, we have asked both food science and material engineering
department about whether if they aid with developing the vegan leather
material, but only received limited response. They are willing to provide

Management Report.doc 2014Jan13 Page 1/2

some advices, but can’t play the major role of development as this is not
something they are familiar with. For the next week, we will be contacting
fashion and chemistry department for their interest.
● Acquiring access to test materials – We are going to be talking to the ISE
labs in helping us get access to certain specialized equipment that will
allow us to do some further testing on out materials
Problems
● Getting a functional website started – A key aspect of studying other
firms in the same domain, is that they have a partially operational website.
Without selling the product. We need to come up with a basic website as
well. We can fund this expense with the capital raised from KickStart VT
and create a website.
● Lack of fully expandable prototype – Even though we do have a sample
vegan leather, but actual production requires much more than this
prototype. We need to develop a functionable production line that can
mass produce such material at large scale, with excellency in both quality
and quantity.
● The sample is far from being able to beat competitors – Leathers needs
to be able to dye into different color, maintain strength under long term
use, waterproof, and provides soft texture to touch. Our sample currently
does not offer all these characteristics.
● Finalizing Raw Materials acquisition– We are having issues sorting out
basic raw material acquisition. We do not have a steady supply of a lot of
shortlisted fruits such as bananas, oranges and mangoes. We plan to go to
a bigger distributor and ask if its possible to acquire in bulk
"""
}
df2 = df2.append(new_row_3, ignore_index=True)
# Out:
# <ipython-input-5-fdd05b1972b7>:72: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df5.append(new_row, ignore_index=True)
# <ipython-input-5-fdd05b1972b7>:101: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df= df.append(new_row_1, ignore_index=True)
# <ipython-input-5-fdd05b1972b7>:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row_2, ignore_index=True)
# <ipython-input-5-fdd05b1972b7>:204: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row_3, ignore_index=True)

# %%
import pandas as pd

# Use triple-quoted strings to preserve the formatting
original_text = """
To: Howard Haines
From: Mackay Kier
Subject: Mackay’s Management Report – Week ending 01/30/22
Company: Oceanic Reef Restorers

Priorities
I am working on these priorities:


Team Task Distribution
Team Building
Problem briefing & solution learning
Progress
During this reporting period, I accomplished these tasks:
Acquired Team- Discussed with, briefly interviewed, and selected team of 6 highly qualified individuals. (Mackay)
Provided a Summary of Oceanic Reef Restorers- Created a summary of the roll-out and administration of the company’s mission & vision. (Mackay)
Updated Team on Task Distribution- Briefly outlined the specific tasks each department/individual will be working on. Defined what each task is comprised of and expressed the gaps that need filled. (Mackay)
Plans
During the next week, I plan to finish these tasks:
Carry Out First Team Building Exercise- Gather all team members at the Cellar for individual introductions and team familiarity conversation. (Full Team)
Define Specific Week 2 Tasks Per Team Member- Prepare and sync everyone to the specific task needed for the week's progression. (Mackay)
Conduct Elevator Pitch for Continued Recruitment- Present pitch in Developing Entrepreneurial Ventures course to ask for help, support, or investment. (Mackay)
Problems
I am aware of these problems:


Unsure of Everyone's Availability- Need to discover each team member's school/extra-curricular schedule to effectively plan team-building exercises. (Mackay)
Unsure of Time Needed to Brief/Introduce Team- Some members of the team may acclimate quicker than others. Do not want to prematurely move forward leaving others lost. (Mackay)
Whole Progression Relies on Product Development – Non product engineers may have lower or slowed roles causing slacking or lack of motivation. (David, Nathan, & Mackay)

"""

# Define the summary
summary = " Week 1 Created the team and MOKR. Plan to get to know each other if schedules allow for it.  Decided task roles for each team member. Plan to recruit others and select tasks for next week. They are concerned that team members will take different amounts of time to feel a part of the team and contribute but don’t have plans for mitigating."


# Create a DataFrame
df3 = pd.DataFrame({'Original Text': [original_text], 'Summary': [summary]})
# Define the new row data as a dictionary
new_row = {
    'Original Text': """
To: Howard Haines
From: Mackay Kier
Subject: Mackay’s Management Report – Week ending 02/06/22
Company: Oceanic Reef Restorers
Project Report 1 Date: 03/02/22

Priorities
I am working on these priorities:


Team Task Explanations & Metrics
Building Inclusive Advisory Board
Finishing Creating Experimental Coral Habitat
Progress
During this reporting period, I accomplished these tasks:
Created Working Document of Tasks for Each Department- Divided team into departments (product engineers, social media relations, & foreign affairs) and drew out a list of work tasks needed to be completed by 05/08 (Mackay)
Developed and Refined the Business Model Canvas- Created a summary of the nine elements vital to visualizing what elements are important and the key areas that need addressing in our new venture. (Full Team)
Uploaded Social Media Photo Content- Transferred a portion of personal photography applicable to social media campaign promotion. (Mackay)
Plans
During the next week, I plan to finish these tasks:
Contact & Gather Advisory Board Members- Message seven different hopeful advisory board members about insight, support, and involvement. (Mackay)
Implant Coral Into Experiment Tank- Prepare, design, and add three different coral types into the pre-acclimated experiment tank. (Mackay)
Support and Manage Completion of Team Tasks- Help team establish, understand, and fulfill their chosen week 2 tasks. (Full Team)
Lukas - Makeup rating scale for country viability
Aiden - Read the articles provided and gather leads on the efforts of other organizations and the practices that are already in place.
Nathan - obtain sds of the neutralizer to see the safety aspect of such
David - Develop a possible container shape
Chris - Brainstorm/determine the perfect product knick-knack for awareness campaign
(cost, structure, usage, roll-out procedures, pricing/donation strategy & focal point)
Evaluate crowdfunding platforms and campaigns for potential usability in capital incurment (gofundme, indigogo, kickstarter, etc.)
Ian - Compile material useful in social media posts & Create a launch schedule (when to roll-out, how often, on what platforms, which topics/contents per day, awareness/viral algorithm?)

Problems
I am aware of these problems:


Unsure of Advisor Availability- Need to discover each advisor's schedule to effectively plan an advisory board meeting and further professional involvement.
Transportation of Coral Could Cause Major Stress/Loss- Coral needs to be carefully transported and implanted into the experiment tank within a few minutes/hours.
Team Tasks May Take Different Levels of Involvement– Will have to address each team member and their tasks accordingly whilst not hindering others success.

    """,

 "Summary":"Week 2 Assigned tasks to team mates as planned but also developed a business model canvas and uploaded photos to social media accounts. No mention of the planned team building or recruitment mentioned previously. Plan to reach out to advisory board members, implant coral into experimental tank, create country criteria scale, competitor analysis, determine safety of the neutralizer, design container shape, determine product knick-knack for awareness campaign, explore crowdfunding, and create social media campaign outline. Still concerned about teammate overlap (needs a quick intervention)as well as advisory board availability and coral transportation. "

}

# Append the new row to the DataFrame
df3 = df3.append(new_row, ignore_index=True)
# Define the new row
new_row_2 = {
    'Original Text': """
To: Howard Haines
From: Mackay Kier
Subject: Mackay’s Management Report – Week ending 02/13/22
Company: Oceanic Reef Restorers

Priorities
I am working on these priorities:


Establishing Which Awareness Campaign Product to Launch
Building Inclusive Advisory Board
Review and Choose Top 3 Destinations for Venture Launch
Progress
During this reporting period, I accomplished these tasks:
Implanted Coral into Experimental Tank- Prepared, designed, and added three different coral types into the pre-acclimated experimental tank. (Mackay)
Recruited Two More Specialized Team Members- Applied for, interviewed, and “hired” two new members from a different course to help with 3D modeling design and creation (Mackay)
Scheduled Meetings with Industry Advisors- Contacted two advisors not previously known about venture introduction and potential fit for advisory board placement. (Mackay)
Plans
During the next week, I plan to finish these tasks:
Meet With, Contact & Gather Advisory Board Members – Carry out two introduction meetings with Sean Collins and Shannon Kelly, and contact the remaining five different hopeful advisory board members about insight, support, and involvement. (Mackay)
Review & Choose Awareness Campaign Product Knick-Knack – Review, choose, and hopefully order components needed for the awareness campaign knick-knack. (Mackay, Chris, Ian)
Review & Choose Top 3 Destination for Venture Launch – Review, choose, and discuss top 3 locations for venture launch. Discern next actions for discovering viability in these 3 locations. (Mackay & Lucas)
Support and Manage Completion of Team Tasks- Help team establish, understand, and fulfill their chosen week 3 tasks. (Full Team)
Lukas – Finish and present results of location ranking excel file (highlight top 3 potential locations for further review)
Aiden – Present findings on competitor reviews and share 5 important antilogs/analogs from industry review
Nathan – Research, record, and discuss alternative methods to acid absorption posts
David – Cross reference design ideas with any like products currently available (compare to other industry and uses – try to discover 3 similar and separate uses for each complementary product)
Chris – Present findings for product knick-knack for awareness campaign & help set up ordering procedures
(cost, structure, usage, roll-out procedures, pricing/donation strategy & focal points)
Ian – Finish, review, and determine necessary steps for social media roll out (solidify post schedule, platform choice, and begin drawing up account features)

Problems
I am aware of these problems:


Knick Knack Product Idea is Limited by Price & Availability- Product choice is going to be restricted to which options fit into the budget and where/how these materials can be acquired.
The Complexity of Choosing Venture Launch Location- 52 different locations being rated and discussed on a scale with 5 varying categories/parameters. Uncertain yet if three or even one location fits ideally into each category.
Time Commitment of Everyone Involved – This week is test week for every member of the group. Individuals like myself have 4 tests between Monday and Thursday. The time needed to devote towards exam preparation will most likely slow project progression.

    """,
    'Summary': """
    Week 3
Coral successfully implanted, advisory board members scheduled, and additional team recruited. No other teammate progress reported and plans look similar to prior week. Intervention is needed to ensure proper reporting. Plan on recruiting more advisory board members, reviewing and deciding on top 3 locations to launch and knick knack for the awareness campaign. Concerned about decisions planned for the week but no steps to mitigate concerns.

   """
}


# Append the new row to the DataFrame
df3 = df3.append(new_row_2, ignore_index=True)
new_row3 = {
    'Original Text': """
  To: Howard Haines
From: Mackay Kier
Subject: Mackay’s Management Report – Week ending 02/20/22
Company: Oceanic Reef Restorers

Priorities
I am working on these priorities:


Make Final Revisions & Publish Company Website
Building Inclusive Advisory Board
Focus on Customer Discovery (Top 5 Individuals, Organizations, & Industries)
Progress
During this reporting period, I accomplished these tasks:
Submitted Application for Seed Funding- Designed, filled out, and presented application for VT KickStarter seed funding event. (Mackay)
Applied for VT Incubator Program- Applied Oceanic Reef Restorers for a spot in VT’s Incubator Program to gain more resources, funding, and network connections to help progression continue. (Mackay)
Discovered Availability, Price, and Shipment Time for Awareness Knick-Knack – Outlined and displayed all the necessary information for the potential use of bracelets as our awareness campaign knick-knack product. (Chris)
Plans
During the next week, I plan to finish these tasks:
Contact & Gather Remaining Advisory Board Members – Contact the remaining hopeful advisors not yet on the board. (Mackay)
Make Final Revisions & Publish Company Website – Reconfigure the “About” page to include solutions, hyperlink social accounts, and integrate new email into the “Join” tab. (Mackay, Chris, Ian)
Determine 5 Individuals, Organizations, & Industries of Target Market – Review, choose, and discuss top 5 individuals, organizations, and industries of our target market (Mackay, Lucas, & Aiden)
Support and Manage Completion of Team Tasks- Help team establish, understand, and fulfill their chosen week 3 tasks. (Full Team)
Lukas – Finish launch site rating document & try to discover which government individuals/agencies control funding related to our venture in the top 3 locations
Aiden – Determine 5-10 medicines & supplements that were derived from reefs (record the company who created it and contact page where contacts can be found)
Nathan – Research, record, and discuss alternative methods to acid absorption posts (watch bleaching video sent to group for more basic info on the problem) *continued from Week 3*
David – Cross reference design ideas with any like products currently available (compare to other industry and uses – try to discover 3 similar and separate uses for each complementary product) *continued from Week 3*
Chris – Discover and list specifics for sticker knick-knack idea & support Ian with website publishing
Ian – Help make final changes to company website & update/create social media profiles to provide connection to published webpage

Problems
I am aware of these problems:


Knick Knack Product Ordering Delayed by Seed Funding Disbursement- Product knick-knack has a viable solution ready to be ordered, yet in order to get the most products for our budget we have to wait for seed funding decision.
Difficult to Identify Individuals for Target Market- Can't determine which individuals to contact within the right government and NGO until the launch location has been identified. Can focus on medicine/nutritional companies for the time being.
Current Website Platform May Not Have Features Desired– The final few revisions and updates on the company website may be more difficult to implement if website creator platform doesn’t support the features we want.

    """,
    'Summary': """
 Week 4

Knick-knack decision made, unplanned application for seed funding and incubator participation. No further progress report on individual team tasks but different tasks for the coming week. Need to intervene regarding reporting requirements and potential lack of progress. Still recruiting for an advisory board, needs encouragement to create specific and measurable goals due to continuous efforts over 3 weeks. Decision about top locations planned as well as publishing their website. Concerned about the top locations decision, the launch of the website, and funding for the knock-knacks (only one that has a way to mitigate via seed funding application-intervention needed for lack of mitigating plans for additional issues).


    """
}
df3 = df3.append(new_row3, ignore_index=True)
# Print the updated DataFrame
print(df3)
# Out:
#                                        Original Text  \
# 0  \nTo: Howard Haines\nFrom: Mackay Kier\nSubjec...
# 1  \nTo: Howard Haines\nFrom: Mackay Kier\nSubjec...
# 2  \nTo: Howard Haines\nFrom: Mackay Kier\nSubjec...
# 3  \n  To: Howard Haines\nFrom: Mackay Kier\nSubj...
#
#                                              Summary
# 0   Week 1 Created the team and MOKR. Plan to get...
# 1  Week 2 Assigned tasks to team mates as planned...
# 2  \n    Week 3\nCoral successfully implanted, ad...
# 3  \n Week 4\n\nKnick-knack decision made, unplan...
# <ipython-input-5-c956e1e662d5>:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df3.append(new_row, ignore_index=True)
# <ipython-input-5-c956e1e662d5>:146: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df3.append(new_row_2, ignore_index=True)
# ...

# %%
import pandas as pd
#SIGNET
# Use triple-quoted strings to preserve the formatting
original_text = """
Subject:	Team Management Report – Week 1  January 31, 2022

Sam Eisenberg, Macs Tantawi

Priorities
We are working on these priorities:

Finalize an idea
Finalize team members
Write out a company plan/direction
Arrange meeting time

Progress
During this reporting period, we accomplished these tasks:

Finalized an idea – Idea is agreed upon and our team will now continue to consolidate ideas and work further towards a business plan
Finalized team members – Confirmed 2 team members as of now. The team may continue to grow because we have a finalized idea. We will continue to reach out to interested people who may want to join

Plans
During the next week, we plan to finish these tasks:

Formally write down a business plan – Meet after learning more about business models and market research to formalize a direction for the company (Macs, Sam)
Arrange meet up for team building – Find a time to meet and discuss each others prior arrangements and interests (Macs, Sam)

Examples:

Evaluate three learning management systems – Review inetoo (in-person demonstration scheduled for Thursday, 19 May), Edmodo (we have a sign-on to the system) and Agilix BrainHoney (to be scheduled). See Problems, below. (Rob, Kirk)

"""

# Define the summary


# Create a DataFrame
df8 = pd.DataFrame({'Original Text': [original_text]})
# Define the new row data as a dictionary
new_row = {
    'Original Text': """
Subject:	 Sling Ring Management Report – Week 2  Feb 7, 2022

Sam Eisenberg, Macs Tantawi

Priorities
We are working on these priorities:

Contact Chinese Manufacturers
Contact Virginia Tech
Arrange meeting time

Progress
During this reporting period, we accomplished these tasks:

Finalized an idea – We came to the idea of the Sling Ring
Finalized team members – Confirmed 2 team members.
Ask about Ring vs Bracelet- overall market research is needed
Plans
During the next week, we plan to finish these tasks:

Formally write down a business plan – Meet after learning more about business models and market research to formalize a direction for the company (Macs, Sam)
Arrange meet up for team building – Find a time to meet and discuss each others prior arrangements and interests (Macs, Sam)
Problems
We are aware of these problems:

Potential issues with legalities– VT police use Hokie ID
China is ghosting us– Chinese silicone manufacturers are annoying to contact
Form Factor Popularity– After market research, the form factor of our ring may not appeal to the mass population
What's the barrier of getting business stolen– What's stopping other businesses from taking our market


"""
}

# Append the new row to the DataFrame
df8 = df8.append(new_row, ignore_index=True)
# Define the new row
new_row_2 = {
    'Original Text': """
Subject:	Team Management Report – Week 3  Feb 13, 2022
Student 1, Student 2
Priorities
We are working on these priorities:

Order Samples
Contact Virginia Tech
Arrange meeting time
Start Expense sheet
Form Business email
Progress
During this reporting period, we accomplished these tasks:

Contact the Chinese– We got in contact with MANY Chinese suppliers
Identified contact – Head of Student ID Card department
Set meeting time- Sometime Friday
Plans
During the next week, we plan to finish these tasks:

Make all business accounts– Make an email account for the business to avoid Chinese spam (Student1)
Arrange to meet up for team building – Find a time to meet and discuss each other's prior arrangements and interests (Student1, Student2)
Order Samples from China – Pick a few solid suppliers to collect samples from (Student1)
Problems
We are aware of these problems:

Potential issues with legalities– University police use the Campus ID
China is stalking us– Chinese manufacturers are adding us on LinkedIn
Form Factor Popularity– After market research, the form factor of our ring may not appeal to the mass population


   """
}


# Append the new row to the DataFrame
df8 = df8.append(new_row_2, ignore_index=True)

# Print the updated DataFrame
print(df8)
# Out:
#                                        Original Text
# 0  \nSubject:\tTeam Management Report – Week 1  J...
# 1  \nSubject:\t Sling Ring Management Report – We...
# 2  \nSubject:\tTeam Management Report – Week 3  F...
# <ipython-input-19-260a58d03a66>:78: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df8 = df8.append(new_row, ignore_index=True)
# <ipython-input-19-260a58d03a66>:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df8 = df8.append(new_row_2, ignore_index=True)

# %%
import pandas as pd

# Use triple-quoted strings to preserve the formatting
original_text = """

"""


# Create a DataFrame
df = pd.DataFrame({'Original Text': [original_text]})

# %%
pip install transformers datasets evaluate rouge_score

# %%
pip install tensorflow

# %%
from langchain import HuggingFacePipeline
from transformers import AutoTokenizer
import transformers
import torch

model = "meta-llama/Llama-2-7b-chat-hf"

tokenizer = AutoTokenizer.from_pretrained(model)

pipeline = transformers.pipeline(
    "text-generation", #task
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
    max_length=1000,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import TextDataset, DataCollatorForLanguageModeling
from transformers import Trainer, TrainingArguments


model_name = "meta-llama/Llama-2-7b-chat-hf"
model = AutoModelForCausalLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)


train_dataset = TextDataset(
    tokenizer=tokenizer,
    file_path=df,
    block_size=128,
)


data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False
)

# Training arguments
training_args = TrainingArguments(
    output_dir="./my_model",
    overwrite_output_dir=True,
    num_train_epochs=1,
    per_device_train_batch_size=4,
    save_steps=10_000,
    save_total_limit=2,
)

# Create Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_dataset,
)

# Train the model
trainer.train()

# Save the model
model.save_pretrained("./my_model")
tokenizer.save_pretrained("./my_model")

# %%
def generate_summaries(input_df, llm):
    summaries = []

    for text in input_df['Original Text']:
        input_prompt = f"""
                      Summarize the Following in 3- 4 sentences and dertemine if progress is made week to week

                      {text}

                      Summary:
                      """
        generated_text = llm(input_prompt, max_length=100, num_return_sequences=1, length_penalty= 0.2)
        output = generated_text[0]['generated_text']
        summaries.append(output)

    return summaries

summaries = generate_summaries(df, llm=pipeline)

for i, summary in enumerate(summaries):
    print(f"Sample {i + 1} Summary:")
    print(summary)
    print("Correct Summary:")
    print(df['Summary'][i])
    print("\n")
# Out:
# Sample 1 Summary:
#
#                       Summarize the Following in 3- 4 sentences and dertemine if progress is made week to week
#
#
#   To: VRSS Management Team
#     From: David Schlingloff
#     Subject: VRSS Management Report – Week ending January 30th, 2022
#     Copies: Management Team, Advisors
#
#     Priorities
#     We are working on these priorities:
#     1. Finalize a set of interested and motivated team members.
#     2. Define competitors to the VRSS product
# Correct Summary:
# Week 1 Created the team and MOKR. Plan to find competitors and understand technology needed. They lack the knowledge to build a streaming service solution and it is unclear who their customers are that would pay for it. Identified problems but don’t have plans for mitigating.
#
#
# Sample 2 Summary:
#
#                       Summarize the Following in 3- 4 sentences and dertemine if progress is made week to week
#
#
#     To: VRSS Management Team
#     From: David Schlingloff
# ...

# %%
from transformers import AutoTokenizer
import pandas as pd


tokenized_examples = []

def tokenize_inputs(row):
    start_prompt = "Summarize the following into 2-4 sentences.\n\n"
    end_prompt = "Summarize\n\n"
    input_text = start_prompt + row['Original Text'] + end_prompt
    summary = row['Summary']

    input_ids = tokenizer(input_text, padding=True, truncation=True, max_length=512, return_tensors='pt').input_ids
    label_ids = tokenizer(summary, padding=True, truncation=True, max_length=512, return_tensors='pt').input_ids

    tokenized_example = {
        'input_ids': input_ids,
        'labels': label_ids
    }

    tokenized_examples.append(tokenized_example)


df.apply(tokenize_inputs, axis=1)
# Out:
# 0    None
# 1    None
# 2    None
# 3    None
# dtype: object

# %%
llm = HuggingFacePipeline(pipeline = pipeline, model_kwargs = {'temperature':0})

# %%
print(df)
# Out:
#                                        Original Text
# 0  \n  To: VRSS Management Team\n    From: David ...

# %%
pip install jsonlines

# %%
from langchain import PromptTemplate, LLMChain
from google.colab import drive
drive.mount('/content/drive')

df = df8
df_objectives = df7

template = "Write a summary in 2 - 4 sentences for each week and determine if the teams are making progress towards their objectives based on the week prior. Objectives: [df7]"

prompt = PromptTemplate(template=template, input_variables=["text", "objectives"])

llm_chain = LLMChain(prompt=prompt, llm=llm)

summaries = []

for index, row in df.iterrows():
    text = row['Original Text']
    df_objectives = df7
    inputs = {"text": text, "objectives": df7}
    summary = llm_chain.run(inputs)
    summaries.append(summary)

df['Summaries'] = summaries

df.to_csv("your-data-with-summaries.csv", index=False)
output_csv_path = "/content/drive/My Drive/your-data-with-summaries.csv"
df.to_csv(output_csv_path, index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from langchain import PromptTemplate, LLMChain
from google.colab import drive
drive.mount('/content/drive')

df = df5

template = "Write a summary of each report in 4 sentences and determine if the team is meeting the objectives listed for their project each week Also determine if the team is making progress based on their plans the week prior."

# Create a PromptTemplate
prompt = PromptTemplate(template=template, input_variables=["text", "df5"])

llm_chain = LLMChain(prompt=prompt, llm=llm)

summaries = []

for _, row in df.iterrows():
    input_data = {"text": row['Original Text']}
    summary = llm_chain.run(input_data)
    summaries.append(summary)

df['Summaries'] = summaries

df.to_csv("your-data-with-summaries.csv", index=False)
output_csv_path = "/content/drive/My Drive/your-data-with-summaries.csv"
df.to_csv(output_csv_path, index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install rouge-score
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=edc51c5711252b0964d6f9454687d4b0f899492e01c44ecf9642931db9dd941c
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# ...

# %%
from rouge_score import rouge_scorer

# %%
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)

# %%
reference_summary = "Sent out the previously created interest survey and tried out an HTC Vive but didn’t  function with Youtube App. Scheduled time with advisory board and potential team member. Plan to try an Oculus Go, analyze the survey data, and prepare for the project review. They still lack the knowledge to build a streaming service solution, the renting of the vr equipment is too burdensome  due to rental policies. They continue to have the same problems of website creation and marketing  but don’t have plans for mitigating. Will need to intervene to get them unstuck."
candidate_summary = """1. Based on the objectives listed at the beginning of the report, it seems that the team is not making much progress. They have only completed one task from their list of priorities and have not made any progress on their plans for the upcoming week.
2. The team is still facing challenges with renting equipment and creating a reliable streaming service. They have not been able to rent an Oculus Go or Oculus Quest due to limited rentals, and they still lack experience with software/website creation.
3. The team is also struggling with their marketing efforts/strategy. They recognize that they will need to be aggressive in their marketing and advertising to acquire customers and produce sales, but they have not developed a plan for how"
"""
scores = scorer.score(reference_summary, candidate_summary)
for key in scores:
    print(f'{key}: {scores[key]}')
# Out:
# rouge1: Score(precision=0.375, recall=0.5, fmeasure=0.42857142857142855)
# rouge2: Score(precision=0.09448818897637795, recall=0.12631578947368421, fmeasure=0.10810810810810811)
# rougeL: Score(precision=0.1640625, recall=0.21875, fmeasure=0.1875)

# %%
reference_summary = "Coral successfully implanted, advisory board members scheduled, and additional team recruited. No other teammate progress reported and plans look similar to prior week. Intervention is needed to ensure proper reporting. Plan on recruiting more advisory board members, reviewing and deciding on top 3 locations to launch and knick knack for the awareness campaign. Concerned about decisions planned for the week but no steps to mitigate concerns."
candidate_summary ="Summary: The team focused on developing the first prototype and conducting user acceptance testing (UAT). They also started working on the second prototype and identified potential risks and challenges. Progress: The team made good progress in developing the first prototype and conducting UAT, but they encountered some issues with the second prototype."
scores = scorer.score(reference_summary, candidate_summary)
for key in scores:
    print(f'{key}: {scores[key]}')
# Out:
# rouge1: Score(precision=0.21153846153846154, recall=0.16666666666666666, fmeasure=0.1864406779661017)
# rouge2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# rougeL: Score(precision=0.15384615384615385, recall=0.12121212121212122, fmeasure=0.13559322033898305)

# %%
import matplotlib.pyplot as plt

# Example scores (replace with actual scores)
scores = {
    'rouge1': 0.65,
    'rouge2': 0.45,
    'rougeL': 0.55,
    'bleu': 0.75,
    'meteor': 0.80
}

# Plotting
fig, ax = plt.subplots()
metrics = list(scores.keys())
values = list(scores.values())
bars = ax.bar(metrics, values, color='blue')

# Adding labels and title
ax.set_ylabel('Score')
ax.set_title('Summary Evaluation Scores')
ax.set_ylim(0, 1)  # Assuming scores are between 0 and 1

# Adding the scores on top of the bars
for bar, value in zip(bars, values):
    ax.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.02, f'{value:.2f}', ha='center', color='black')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Provided Rouge scores
rouge1_scores = {
    'precision': 0.21153846153846154,
    'recall': 0.16666666666666666,
    'fmeasure': 0.1864406779661017
}

rouge2_scores = {
    'precision': 0.0,
    'recall': 0.0,
    'fmeasure': 0.0
}

rougeL_scores = {
    'precision': 0.15384615384615385,
    'recall': 0.12121212121212122,
    'fmeasure': 0.13559322033898305
}

# Plotting
fig, ax = plt.subplots()
metrics = list(rouge1_scores.keys())
values_rouge1 = list(rouge1_scores.values())
values_rouge2 = list(rouge2_scores.values())
values_rougeL = list(rougeL_scores.values())

# Bar width for better visibility
bar_width = 0.2

# Adding bars for Rouge-1
bars_rouge1 = ax.bar(metrics, values_rouge1, width=bar_width, color='blue', label='Rouge-1')

# Adding bars for Rouge-2
bars_rouge2 = ax.bar([x + bar_width for x in range(len(metrics))], values_rouge2, width=bar_width, color='red', label='Rouge-2')

# Adding bars for Rouge-L
bars_rougeL = ax.bar([x + 2 * bar_width for x in range(len(metrics))], values_rougeL, width=bar_width, color='green', label='Rouge-L')

# Adding labels and title
ax.set_ylabel('Score')
ax.set_title('Rouge Evaluation Scores')
ax.legend()

# Display the plot
plt.show()

# %%
from rouge import Rouge





# Reference summary
reference_summary = ["Sent out the previously created interest survey and tried out an HTC Vive but didn’t  function with Youtube App. Scheduled time with advisory board and potential team member. Plan to try an Oculus Go, analyze the survey data, and prepare for the project review. They still lack the knowledge to build a streaming service solution, the renting of the vr equipment is too burdensome  due to rental policies. They continue to have the same problems of website creation and marketing  but don’t have plans for mitigating. Will need to intervene to get them unstuck. "]

# Generated summary
generated_summary = [""" * Refined target consumers and defined advisory board
            * Scheduled VR equipment rental and identified specific details about 3 competitors
            * Plans to finish tasks include creating an interest survey and obtaining and using VR equipment
            * Problems include lack of experience with software/website creation, VR equipment implementation requiring resources, and inadequate marketing efforts/strategy
            * Management Team and Advisors were copied on the report
            * The team needs assistance/intervention in the areas of software/website creation and marketing
            * The team is on track with their priorities and progress
            * The report provides a detailed overview of the team's activities and challenges
            * The management team should consider providing additional resources and support to help the team overcome their challenges
            * The team should continue to"
"""]
rouge = Rouge()
scores = rouge.get_scores(generated_summary, reference_summary)

print(scores)

# %%
from google.colab import files
import jsonlines
import os
import pandas as pd
from langchain import PromptTemplate, LLMChain

uploaded = files.upload()
file_name = list(uploaded.keys())[0]

if file_name.endswith(".jsonl"):
    preprocessed_file_path = "howard_efsd_assumptions.jsonl"

    with open(preprocessed_file_path, 'w', encoding='utf-8') as output_file:
        with open(file_name, 'r', encoding='utf-8') as input_file:
            for line in jsonlines.Reader(input_file):
                text = line["text"]
                output_file.write(text + "\n")

    print(f"Preprocessed file saved as {preprocessed_file_path}")

    template = """
              Write a concise summary of the following text delimited by triple backquotes.
              Return your response which covers the key points of the text.
              Make the summary 2-4 sentences and determine if the students are doing good work.
              Determine if the team needs assistance/intervention

              ```{text}```
              BULLET POINT SUMMARY:
           """
    prompt = PromptTemplate(template=template, input_variables=["text"])

    llm_chain = LLMChain(prompt=prompt, llm=llm)

    summaries = []

    # Set a counter to limit processing to 50 lines
    counter = 0

    with open(preprocessed_file_path, 'r', encoding='utf-8') as preprocessed_file:
        for text in preprocessed_file:
            summary = llm_chain.run(text)
            summaries.append(summary)
            counter += 1

            # Break the loop after processing 50 lines
            if counter >= 50:
                break

    # Print the first 5 summaries as an example
    for i, summary in enumerate(summaries[:5]):
        print(f"Summary {i + 1}: {summary}")

else:
   print("No files were uploaded or the uploaded file is not in the JSONLines format.")
# Out:
#      <input type="file" id="files-8bd4bc17-4254-4ac1-9d1e-285a0ad187f2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8bd4bc17-4254-4ac1-9d1e-285a0ad187f2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ls
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-12-47ff98f8b5ff> in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('ls', '')
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/alias.py in __call__(self, rest)
#     184             cmd = '%s %s' % (cmd % tuple(args[:nargs]),' '.join(args[nargs:]))
#     185
# --> 186         self.shell.system(cmd)
#     187
#     188 #-----------------------------------------------------------------------------
#
# ...

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv("your-data-with-summaries.csv")

# View the contents of the DataFrame
print(df)
# Out:
#                                        Original Text  \
# 0  \n  To: VRSS Management Team\n    From: David ...
# 1  \n    To: VRSS Management Team\n    From: Davi...
# 2  \n   To: VRSS Management Team\nFrom: David Sch...
# 3  \n    To: VRSS Management Team\nFrom: David Sc...
#
#                                            Summaries
# 0   - Team is working on finalizing a set of inte...
# 1   - Team is working on finalizing a set of inte...
# 2   - Refined target consumers\n            - Def...
# 3   - The team is working on priorities such as l...
